# %% [markdown]
# # Warm up
# Let's start with some warm up exercises to get you familiar with the database and do some SQL querying.
# Make sure to have downloaded the NBA dataset form Kaggle as described in the README.

# %%
import sqlite3 as sql
import pandas as pd
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


## TODO: Use pathlib to get the path to the data directory. Path(__file__) won't work in a Jupyter notebook.
DATA_PATH = Path.cwd() / 'data' / 'nba.sqlite'

# %% [markdown]
# ## Create a SQLite connection and run some SQL queries

# %%
con = sql.connect(DATA_PATH)  # connect to the database
query = 'SELECT * FROM game LIMIT 10'  # write a query that selects the first 10 rows from the game table
top_10_game = pd.read_sql(query, con)  # read the query into a pandas dataframe
top_10_game.head() # print the dataframe
# Out:
#   season_id team_id_home team_abbreviation_home           team_name_home  \
# 0     21946   1610610035                    HUS          Toronto Huskies
# 1     21946   1610610034                    BOM        St. Louis Bombers
# 2     21946   1610610032                    PRO  Providence Steamrollers
# 3     21946   1610610025                    CHS            Chicago Stags
# 4     21946   1610610028                    DEF          Detroit Falcons
#
#       game_id            game_date matchup_home wl_home  min  fgm_home  ...  \
# 0  0024600001  1946-11-01 00:00:00  HUS vs. NYK       L    0      25.0  ...
# 1  0024600003  1946-11-02 00:00:00  BOM vs. PIT       W    0      20.0  ...
# 2  0024600002  1946-11-02 00:00:00  PRO vs. BOS       W    0      21.0  ...
# 3  0024600004  1946-11-02 00:00:00  CHS vs. NYK       W    0      21.0  ...
# 4  0024600005  1946-11-02 00:00:00  DEF vs. WAS       L    0      10.0  ...
#
#    reb_away  ast_away stl_away blk_away tov_away  pf_away  pts_away  \
# 0      None      None     None     None     None      NaN      68.0
# 1      None      None     None     None     None     25.0      51.0
# 2      None      None     None     None     None      NaN      53.0
# 3      None      None     None     None     None     22.0      47.0
# 4      None      None     None     None     None      NaN      50.0
#
#    plus_minus_away video_available_away     season_type
# 0                2                    0  Regular Season
# 1               -5                    0  Regular Season
# 2               -6                    0  Regular Season
# 3              -16                    0  Regular Season
# 4               17                    0  Regular Season
#
# [5 rows x 55 columns]

# %%
# let's look at the schema of the database
# TODO: sqlite_master is the name of the table you want to inspeact: Replace TABLE_NAME with the name of the table you want to inspect
query = """
    SELECT *
    FROM sqlite_master
    WHERE type='table';
"""

pd.read_sql(query, con).sort_values('name')
# Out:
#      type                 name             tbl_name  rootpage  \
# 10  table   common_player_info   common_player_info      4314
# 13  table  draft_combine_stats  draft_combine_stats      4313
# 14  table        draft_history        draft_history      4318
# 0   table                 game                 game        52
# 5   table            game_info            game_info      9457
# 1   table         game_summary         game_summary      4564
# 4   table     inactive_players     inactive_players      7443
# 6   table           line_score           line_score     10084
# 3   table            officials            officials      6747
# 2   table          other_stats          other_stats      6025
# 7   table         play_by_play         play_by_play     12362
# 8   table               player               player         2
# 9   table                 team                 team        51
# 11  table         team_details         team_details      4310
# 12  table         team_history         team_history      4312
# 15  table     team_info_common     team_info_common      4320
#
#                                                   sql
# 10  CREATE TABLE "common_player_info" (\n"person_i...
# 13  CREATE TABLE "draft_combine_stats" (\n"season"...
# 14  CREATE TABLE "draft_history" (\n"person_id" TE...
# 0   CREATE TABLE "game" (\n"season_id" TEXT,\n  "t...
# 5   CREATE TABLE "game_info" (\n"game_id" TEXT,\n ...
# 1   CREATE TABLE "game_summary" (\n"game_date_est"...
# 4   CREATE TABLE "inactive_players" (\n"game_id" T...
# 6   CREATE TABLE "line_score" (\n"game_date_est" T...
# 3   CREATE TABLE "officials" (\n"game_id" TEXT,\n ...
# 2   CREATE TABLE "other_stats" (\n"game_id" TEXT,\...
# 7   CREATE TABLE "play_by_play" (\n"game_id" TEXT,...
# 8   CREATE TABLE "player" (\n"id" TEXT,\n  "full_n...
# 9   CREATE TABLE "team" (\n"id" TEXT,\n  "full_nam...
# 11  CREATE TABLE "team_details" (\n"team_id" TEXT,...
# 12  CREATE TABLE "team_history" (\n"team_id" TEXT,...
# 15  CREATE TABLE "team_info_common" (\n"team_id" T...

# %%
# let's see all the tables we have in the database
# TODO: Filter for tables only
query = """
    SELECT name
    FROM sqlite_master
    WHERE type = 'table'
"""
pd.read_sql(query, con)
# Out:
#                    name
# 0                  game
# 1          game_summary
# 2           other_stats
# 3             officials
# 4      inactive_players
# 5             game_info
# 6            line_score
# 7          play_by_play
# 8                player
# 9                  team
# 10   common_player_info
# 11         team_details
# 12         team_history
# 13  draft_combine_stats
# 14        draft_history
# 15     team_info_common

# %%
# let's have a look at the columns in the game table
query = """
    PRAGMA table_info(draft_combine_stats)
"""
pd.read_sql(query, con)
# Out:
#     cid                          name  type  notnull dflt_value  pk
# 0     0                        season  TEXT        0       None   0
# 1     1                     player_id  TEXT        0       None   0
# 2     2                    first_name  TEXT        0       None   0
# 3     3                     last_name  TEXT        0       None   0
# 4     4                   player_name  TEXT        0       None   0
# 5     5                      position  TEXT        0       None   0
# 6     6               height_wo_shoes  REAL        0       None   0
# 7     7         height_wo_shoes_ft_in  TEXT        0       None   0
# 8     8                height_w_shoes  REAL        0       None   0
# 9     9          height_w_shoes_ft_in  TEXT        0       None   0
# 10   10                        weight  TEXT        0       None   0
# 11   11                      wingspan  REAL        0       None   0
# 12   12                wingspan_ft_in  TEXT        0       None   0
# 13   13                standing_reach  REAL        0       None   0
# 14   14          standing_reach_ft_in  TEXT        0       None   0
# 15   15                  body_fat_pct  TEXT        0       None   0
# 16   16                   hand_length  TEXT        0       None   0
# 17   17                    hand_width  TEXT        0       None   0
# 18   18        standing_vertical_leap  REAL        0       None   0
# 19   19             max_vertical_leap  REAL        0       None   0
# 20   20             lane_agility_time  REAL        0       None   0
# 21   21    modified_lane_agility_time  REAL        0       None   0
# 22   22          three_quarter_sprint  REAL        0       None   0
# 23   23                   bench_press  REAL        0       None   0
# 24   24      spot_fifteen_corner_left  TEXT        0       None   0
# 25   25       spot_fifteen_break_left  TEXT        0       None   0
# 26   26          spot_fifteen_top_key  TEXT        0       None   0
# 27   27      spot_fifteen_break_right  TEXT        0       None   0
# 28   28     spot_fifteen_corner_right  TEXT        0       None   0
# 29   29      spot_college_corner_left  TEXT        0       None   0
# 30   30       spot_college_break_left  TEXT        0       None   0
# 31   31          spot_college_top_key  TEXT        0       None   0
# 32   32      spot_college_break_right  TEXT        0       None   0
# 33   33     spot_college_corner_right  TEXT        0       None   0
# 34   34          spot_nba_corner_left  TEXT        0       None   0
# 35   35           spot_nba_break_left  TEXT        0       None   0
# 36   36              spot_nba_top_key  TEXT        0       None   0
# 37   37          spot_nba_break_right  TEXT        0       None   0
# 38   38         spot_nba_corner_right  TEXT        0       None   0
# 39   39   off_drib_fifteen_break_left  TEXT        0       None   0
# 40   40      off_drib_fifteen_top_key  TEXT        0       None   0
# 41   41  off_drib_fifteen_break_right  TEXT        0       None   0
# 42   42   off_drib_college_break_left  TEXT        0       None   0
# 43   43      off_drib_college_top_key  TEXT        0       None   0
# 44   44  off_drib_college_break_right  TEXT        0       None   0
# 45   45               on_move_fifteen  TEXT        0       None   0
# 46   46               on_move_college  TEXT        0       None   0

# %%
# let's find the earliest recorded game
query = """
    SELECT game_date
    FROM game
    ORDER BY game_date
    LIMIT 1
"""

print(pd.read_sql(query, con))

# let's find the latest recorded game
query = """
    SELECT game_date
    FROM game
    ORDER BY game_date DESC
    LIMIT 1
"""

print(pd.read_sql(query, con))
# Out:
#              game_date
# 0  1946-11-01 00:00:00
#              game_date
# 0  2023-06-12 00:00:00

# %%
# TODO: Find four interesting facts about the data and write a query to find the answer

# %%
#sight 1
query = """
    SELECT height_w_shoes AS height, max_vertical_leap AS vertical_leap
    FROM draft_combine_stats
    WHERE height_w_shoes IS NOT NULL AND max_vertical_leap IS NOT NULL
"""
df1 = pd.read_sql(query, con)
df1

# %% [markdown]
# To see if taller players generally have a lower or higher vertical leap, we can analyze the height_w_shoes and max_vertical_leap columns. This insight could reveal if taller players tend to have lower verticals or if there's no significant correlation.

# %%
# Assuming df is the DataFrame resulting from the query
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df1, x='height', y='vertical_leap')
plt.title('Correlation between Height and Vertical Leap')
plt.xlabel('Height')
plt.ylabel('Max Vertical Leap')
plt.grid(True)
plt.show()

# %%
#sight 2
query = """
    SELECT position, player_name, three_quarter_sprint
    FROM draft_combine_stats
    WHERE three_quarter_sprint IS NOT NULL
    ORDER BY three_quarter_sprint ASC
    LIMIT 10
"""
df2 = pd.read_sql(query, con)
df2

# %% [markdown]
# Examining the three_quarter_sprint column can help identify the fastest sprint times by player position. This insight would highlight which positions tend to have the fastest sprint speeds and which individual players stand out.

# %%
#sight 3
query = """

    SELECT 
        AVG(CAST(spot_nba_corner_left AS FLOAT)) AS nba_corner_left_accuracy,
        AVG(CAST(spot_nba_top_key AS FLOAT)) AS nba_top_key_accuracy,
        AVG(CAST(spot_college_top_key AS FLOAT)) AS college_top_key_accuracy,
        AVG(CAST(off_drib_college_top_key AS FLOAT)) AS off_drib_college_accuracy
    FROM draft_combine_stats
    WHERE 
        spot_nba_corner_left IS NOT NULL 
        AND spot_nba_top_key IS NOT NULL
        AND spot_college_top_key IS NOT NULL
        AND off_drib_college_top_key IS NOT NULL
"""
df3 = pd.read_sql(query, con)
df3

# %%
# Reshape the DataFrame for easier plotting (if necessary)
accuracy_df = pd.DataFrame({
    'Shot Type': ['NBA Corner Left', 'NBA Top Key', 'College Top Key', 'Off-Dribble College'],
    'Accuracy': [df3['nba_corner_left_accuracy'].iloc[0],
                 df3['nba_top_key_accuracy'].iloc[0],
                 df3['college_top_key_accuracy'].iloc[0],
                 df3['off_drib_college_accuracy'].iloc[0]]
})

plt.figure(figsize=(10, 6))
sns.barplot(data=accuracy_df, x='Shot Type', y='Accuracy', palette='viridis')
plt.title('Shooting Accuracy by Shot Type')
plt.xlabel('Shot Type')
plt.ylabel('Average Shooting Accuracy (%)')
plt.ylim(0, 100)
plt.show()
